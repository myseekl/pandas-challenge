# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
school_data_to_load = Path("Resources/schools_complete.csv")
student_data_to_load = Path("Resources/students_complete.csv")

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %% [markdown]
# **District Summary**

# %%
# Find total number of unique schools; used Xpert Learning Assitant to help with the code.

# Access "school_name" column from the DATAFRAME: school_data_completed 
school_names = school_data_complete["school_name"]

# Generate an empty set to store unique school names
unique_school = set()

# Iterate over the values in the 'school_name' column and add unique school names to the set
for school_name in school_names:
    unique_school.add(school_name)

# Count total number of unique school names
unique_school_count = len(unique_school)

print("Total count of schools:", unique_school_count)
# Out:
# Total count of schools: 15

# %%
# Total students

# Access "Student ID" column from the DATAFRAME: school_data_complete
student_ID = school_data_complete["Student ID"]

# Generate an empty set to store unique student IDs
unique_student_ID = set()

# Iterate over the values in the 'Student ID' column and add unique school names to the set
for student_ID in student_ID:
    unique_student_ID.add(student_ID)

# Count total number of unique student IDs
unique_student_ID_count = len(unique_student_ID)

print("Total count of students in the district:", unique_student_ID_count)
# Out:
# Total count of students in the district: 39170

# %%
# Total budget

# Access "budget" column from the DATAFRAME: school_data_complete
budget = school_data_complete["budget"]

# Calculate total budget
TOTALbudget = budget.sum()

print("Total disctrict budget:", TOTALbudget)
# Out:
# Total disctrict budget: 82932329558

# %%
# Average math Score

# Access "math_score" column from the DATAFRAME: school_data_complete
math_score = school_data_complete["math_score"]

# Caluculate average of math score
AVERAGEmath_score = math_score.mean()
AVERAGEmath_score_rounded = round(AVERAGEmath_score)
AVERAGEmath_score_rounded

print("District average math score:", AVERAGEmath_score_rounded)
# Out:
# District average math score: 79

# %%
# Average reading score

# Access "reading_score" column from the DATAFRAME: school_data_complete
reading_score = school_data_complete["reading_score"]

# Caluculate average of math score
AVERAGEreading_score = reading_score.mean()
AVERAGEreading_score_rounded = round(AVERAGEreading_score)
AVERAGEreading_score_rounded

print("District average reading score:", AVERAGEreading_score_rounded)
# Out:
# District average reading score: 82

# %%
# % passing math; copied from PyCitySchools_starter and modified to use variable made in previous code for total count of students

passing_math_count = school_data_complete[(school_data_complete["math_score"] >= 70)].count()["student_name"]
passing_math_percentage = passing_math_count / float(unique_student_ID_count) * 100
passing_math_percentage = round(passing_math_percentage)

print("Percent of students passing math:", passing_math_percentage,"%")
# Out:
# Percent of students passing math: 75 %

# %%
# % passing reading

passing_reading_count = school_data_complete[(school_data_complete["reading_score"] >= 70)].count()["student_name"]
passing_reading_percentage = passing_reading_count / float(unique_student_ID_count) * 100
passing_reading_percentage = round(passing_reading_percentage)

print("Percent of students passing reading:", passing_reading_percentage,"%")
# Out:
# Percent of students passing reading: 86 %

# %%
# % overall passing; copied from PyCitySchools_starter and modified to use variable made in previous code for total count of students

# Count total number of students that scored greater to or equal to 70% in both math and reading
passing_math_reading_count = school_data_complete[
    (school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)
].count()["student_name"]
# Calculate percent of students passing both in math and reading
overall_passing_percent = passing_math_reading_count / unique_student_ID_count * 100
overall_passing_percent_rounded = round(overall_passing_percent)

print("Percent of students passing both math and reading in the district:", overall_passing_percent_rounded,"%")
# Out:
# Percent of students passing both math and reading in the district: 65 %

# %% [markdown]
# **School Summary**

# %%
# Use the code provided to select the type per school from school_data
school_types = school_data.set_index(["school_name"])["type"]
print(school_types)
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
# Sort student and data into dataframes by high school names
# Huang_HS_df = school_data_complete[school_data_complete["school_name"] == "Huang High School"]
# Figueroa_HS_df = school_data_complete[school_data_complete["school_name"] == "Figueroa High School"]
# Shelton_HS_df = school_data_complete[school_data_complete["school_name"] == "Shelton High School"]
# Hernandez_HS_df = school_data_complete[school_data_complete["school_name"] == "Hernandez High School"]
# Griffin_HS_df = school_data_complete[school_data_complete["school_name"] == "Griffin High School"]
# Wilson_HS_df = school_data_complete[school_data_complete["school_name"] == "Wilson High School"]
# Cabrera_HS_df = school_data_complete[school_data_complete["school_name"] == "Cabrera High School"]
# Bailey_HS_df = school_data_complete[school_data_complete["school_name"] == "Bailey High School"]
# Holden_HS_df = school_data_complete[school_data_complete["school_name"] == "Holden High School"]
# Pena_HS_df = school_data_complete[school_data_complete["school_name"] == "Pena High School"]
# Wright_HS_df = school_data_complete[school_data_complete["school_name"] == "Wright High School"]
# Rodriguez_HS_df = school_data_complete[school_data_complete["school_name"] == "Rodriguez High School"]
# Johnson_HS_df = school_data_complete[school_data_complete["school_name"] == "Johnson High School"]
# Ford_HS_df = school_data_complete[school_data_complete["school_name"] == "Ford High School"]
# Thomas_HS_df = school_data_complete[school_data_complete["school_name"] == "Thomas High School"]
# Thomas_HS_df

# %%
# Find total number of students per school
per_school_counts = school_data_complete.groupby("school_name")["student_name"].count()
per_school_counts
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: student_name, dtype: int64

# %%
# Calculate the total school budget and per capita spending per school from school_data
per_school_budget = school_data_complete.groupby("school_name")["budget"].sum()
per_school_capita = per_school_budget / per_school_counts

# %%
# Calculate the average test scores per school from school_data_complete
per_school_math = school_data_complete.groupby("school_name")["math_score"].mean()
per_school_math = round(per_school_math)
per_school_reading =  school_data_complete.groupby("school_name")["reading_score"].mean()
per_school_reading = round(per_school_reading)

# %%
# Calculate the number of students per school with math scores of 70 or higher from school_data_complete

school_students_passing_math = school_data_complete[school_data_complete["math_score"] >= 70].groupby("school_name")["Student ID"].count()
school_students_passing_math
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: Student ID, dtype: int64

# %%
# Calculate the number of students per school with reading scores of 70 or higher from school_data_complete

school_students_passing_reading = school_data_complete[school_data_complete["reading_score"] >= 70].groupby("school_name")["Student ID"].count()
school_students_passing_reading
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: Student ID, dtype: int64

# %%
# Use the provided code to calculate the number of students per school that passed both math and reading with scores of 70 or higher
students_passing_math_and_reading = school_data_complete[
    (school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)
]
school_students_passing_math_and_reading = students_passing_math_and_reading.groupby(["school_name"]).size()

# %%
# Use the provided code to calculate the passing rates
per_school_passing_math = school_students_passing_math / per_school_counts * 100
per_school_passing_math = round(per_school_passing_math)
per_school_passing_reading = school_students_passing_reading / per_school_counts * 100
per_school_passing_reading = round(per_school_passing_reading)
overall_passing_rate = school_students_passing_math_and_reading / per_school_counts * 100
overall_passing_rate = round(overall_passing_rate)

# %%
# Create a dictionary for per_school_summary
per_school_summary = {
    "School Type": school_types,
    "Total Students": per_school_counts,
    "Total School Budget": per_school_budget,
    "Per Student Budget": per_school_capita,
    "Average Math Score": school_students_passing_math,
    "Average Reading Score": school_students_passing_reading,
    "Percent Passing Math": per_school_passing_math,
    "Percent Passing Reading": per_school_passing_reading,
    "Percent Overall Passing": overall_passing_rate
}

# Convert the dictionary to a DataFrame
per_school_summary_df = pd.DataFrame(per_school_summary)

# Formatting
per_school_summary_df["Total School Budget"] = per_school_summary_df["Total School Budget"].map("${:,.2f}".format)
per_school_summary_df["Per Student Budget"] = per_school_summary_df["Per Student Budget"].map("${:,.2f}".format)

# Display the DataFrame
per_school_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Bailey High School       District            4976  $15,549,641,728.00
# Cabrera High School       Charter            1858   $2,009,159,448.00
# Figueroa High School     District            2949   $5,557,128,039.00
# Ford High School         District            2739   $4,831,365,924.00
# Griffin High School       Charter            1468   $1,346,890,000.00
# Hernandez High School    District            4635  $14,007,062,700.00
# Holden High School        Charter             427     $105,933,149.00
# Huang High School        District            2917   $5,573,322,295.00
# Johnson High School      District            4761  $14,733,628,650.00
# Pena High School          Charter             962     $563,595,396.00
# Rodriguez High School    District            3999  $10,186,904,637.00
# Shelton High School       Charter            1761   $1,860,672,600.00
# ...

# %% [markdown]
# **Highest Performing Schools Based on Percentage of Overall Passing Students in Math and Reading**

# %%
# Sort the schools by `% Overall Passing` in descending order and display the top 5 rows.
top_schools = per_school_summary_df.sort_values(by="Percent Overall Passing", ascending=False)
top_schools.head(5)
# Out:
#                     School Type  Total Students Total School Budget  \
# school_name
# Cabrera High School     Charter            1858   $2,009,159,448.00
# Griffin High School     Charter            1468   $1,346,890,000.00
# Pena High School        Charter             962     $563,595,396.00
# Thomas High School      Charter            1635   $1,705,517,550.00
# Wilson High School      Charter            2283   $3,012,587,442.00
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School      $1,081,356.00                1749
# Griffin High School        $917,500.00                1371
# Pena High School           $585,858.00                 910
# Thomas High School       $1,043,130.00                1525
# Wilson High School       $1,319,574.00                2143
#
#                      Average Reading Score  Percent Passing Math  \
# school_name
# Cabrera High School                   1803                  94.0
# ...

# %% [markdown]
# **Lowest Performing Schools Based on Percentage of Overall Passing Students in Math and Reading**

# %%
# Sort the schools by `% Overall Passing` in ascending order and display the top 5 rows.
bottom_schools = per_school_summary_df.sort_values(by="Percent Overall Passing", ascending=True)
bottom_schools.head(5)
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Figueroa High School     District            2949   $5,557,128,039.00
# Rodriguez High School    District            3999  $10,186,904,637.00
# Ford High School         District            2739   $4,831,365,924.00
# Hernandez High School    District            4635  $14,007,062,700.00
# Huang High School        District            2917   $5,573,322,295.00
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Figueroa High School       $1,884,411.00                1946
# Rodriguez High School      $2,547,363.00                2654
# Ford High School           $1,763,916.00                1871
# Hernandez High School      $3,022,020.00                3094
# Huang High School          $1,910,635.00                1916
#
#                        Average Reading Score  Percent Passing Math  \
# school_name
# ...

# %% [markdown]
# **Math Scores by Grade**

# %%
# per_school_math = school_data_complete.groupby("school_name")["math_score"].mean()
# per_school_math = round(per_school_math)
# per_school_reading =  school_data_complete.groupby("school_name")["reading_score"].mean()
# per_school_reading = round(per_school_reading)

# Use the code provided to separate the data by grade
ninth_graders = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_graders = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_graders = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_graders = school_data_complete[(school_data_complete["grade"] == "12th")]

# Group by `school_name` and take the mean of the `math_score` column for each.
ninth_grade_math_scores = ninth_graders.groupby("school_name")["math_score"].mean()
ninth_grade_math_scores = round(ninth_grade_math_scores)
tenth_grader_math_scores = tenth_graders.groupby("school_name")["math_score"].mean()
tenth_grader_math_scores = round(tenth_grader_math_scores)
eleventh_grader_math_scores = eleventh_graders.groupby("school_name")["math_score"].mean()
eleventh_grader_math_scores = round(eleventh_grader_math_scores)
twelfth_grader_math_scores = twelfth_graders.groupby("school_name")["math_score"].mean()
twelfth_grader_math_scores = round(twelfth_grader_math_scores)

# Create a dictionary of average math grade  per grade per school
math_scores_by_grade_data = {
    "9th_Grade_Math_Score_Average": ninth_grade_math_scores,
    "10th_Grade_Math_Score_Average": tenth_grader_math_scores,
    "11th_Grade_Math_Score_Average": eleventh_grader_math_scores,
    "12th_Grade_Math_Score_Average": twelfth_grader_math_scores
}
# Combine each of the scores above into single DataFrame called `math_scores_by_grade`
math_scores_by_grade_df = pd.DataFrame(math_scores_by_grade_data)

# Minor data wrangling
math_scores_by_grade_df.index.name = None

# Display the DataFrame
math_scores_by_grade_df
# Out:
#                        9th_Grade_Math_Score_Average  \
# Bailey High School                             77.0
# Cabrera High School                            83.0
# Figueroa High School                           76.0
# Ford High School                               77.0
# Griffin High School                            82.0
# Hernandez High School                          77.0
# Holden High School                             84.0
# Huang High School                              77.0
# Johnson High School                            77.0
# Pena High School                               84.0
# Rodriguez High School                          77.0
# Shelton High School                            83.0
# Thomas High School                             84.0
# Wilson High School                             83.0
# Wright High School                             83.0
#
#                        10th_Grade_Math_Score_Average  \
# Bailey High School                              77.0
# ...

# %% [markdown]
# **Reading Score by Grade**

# %%
# Use the code provided to separate the data by grade
ninth_graders = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_graders = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_graders = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_graders = school_data_complete[(school_data_complete["grade"] == "12th")]

# Group by `school_name` and take the mean of the the `reading_score` column for each.
ninth_grade_reading_scores = ninth_graders.groupby("school_name")["reading_score"].mean()
ninth_grade_reading_scores = round(ninth_grade_reading_scores)
tenth_grader_reading_scores = tenth_graders.groupby("school_name")["reading_score"].mean()
tenth_grader_reading_scores = round(tenth_grader_reading_scores)
eleventh_grader_reading_scores = eleventh_graders.groupby("school_name")["reading_score"].mean()
eleventh_grader_reading_scores = round(eleventh_grader_reading_scores)
twelfth_grader_reading_scores = twelfth_graders.groupby("school_name")["reading_score"].mean()
twelfth_grader_reading_scores = round(twelfth_grader_reading_scores)

# Create a dictionary of average reading score per grade per school
reading_scores_by_grade_data = {
    "9th_Grade_Reading_Score_Average": ninth_grade_reading_scores,
    "10th_Grade_Reading_Score_Average": tenth_grader_reading_scores,
    "11th_Grade_Reading_Score_Average": eleventh_grader_reading_scores,
    "12th_Grade_reading_Score_Average": twelfth_grader_reading_scores
}

# Combine each of the scores above into single DataFrame called `reading_scores_by_grade`
reading_scores_by_grade_df = pd.DataFrame(reading_scores_by_grade_data)

# Minor data wrangling
reading_scores_by_grade_df.index.name = None

# Display the DataFrame
reading_scores_by_grade_df
# Out:
#                        9th_Grade_Reading_Score_Average  \
# Bailey High School                                81.0
# Cabrera High School                               84.0
# Figueroa High School                              81.0
# Ford High School                                  81.0
# Griffin High School                               83.0
# Hernandez High School                             81.0
# Holden High School                                84.0
# Huang High School                                 81.0
# Johnson High School                               81.0
# Pena High School                                  84.0
# Rodriguez High School                             81.0
# Shelton High School                               84.0
# Thomas High School                                84.0
# Wilson High School                                84.0
# Wright High School                                84.0
#
#                        10th_Grade_Reading_Score_Average  \
# ...

# %% [markdown]
# **Scores by School Spending**

# %%
# Establish the bins
spending_bins = [0, 585, 630, 645, 680]
labels = ["<$585", "$585-630", "$630-645", "$645-680"]

# %%
# Create a copy of the school summary since it has the "Per Student Budget"
school_spending_df = per_school_summary_df.copy()
school_spending_df
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Bailey High School       District            4976  $15,549,641,728.00
# Cabrera High School       Charter            1858   $2,009,159,448.00
# Figueroa High School     District            2949   $5,557,128,039.00
# Ford High School         District            2739   $4,831,365,924.00
# Griffin High School       Charter            1468   $1,346,890,000.00
# Hernandez High School    District            4635  $14,007,062,700.00
# Holden High School        Charter             427     $105,933,149.00
# Huang High School        District            2917   $5,573,322,295.00
# Johnson High School      District            4761  $14,733,628,650.00
# Pena High School          Charter             962     $563,595,396.00
# Rodriguez High School    District            3999  $10,186,904,637.00
# Shelton High School       Charter            1761   $1,860,672,600.00
# ...

# %%
# Use `pd.cut` to categorize spending based on the bins.
school_spending_df["Spending Ranges (Per Student)"] = pd.cut(school_spending_df["Per Student Budget"], spending_bins, labels=labels)
school_spending_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 # Use `pd.cut` to categorize spending based on the bins.
# ----> 2 school_spending_df["Spending Ranges (Per Student)"] = pd.cut(school_spending_df["Per Student Budget"], spending_bins, labels=labels)
#       3 school_spending_df
#
# File c:\Users\j0nat\anaconda3\envs\dev\Lib\site-packages\pandas\core\reshape\tile.py:257, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     254     if not bins.is_monotonic_increasing:
#     255         raise ValueError("bins must increase monotonically.")
# --> 257 fac, bins = _bins_to_cuts(
#     258     x_idx,
#     259     bins,
#     260     right=right,
#     261     labels=labels,
#     262     precision=precision,
#     263     include_lowest=include_lowest,
#     264     duplicates=duplicates,
# ...

# %%
# Calculate averages for the desired columns.
size_math_scores = per_school_summary_df.groupby(["Total Students"])["Average Math Score"].mean()
size_reading_scores = per_school_summary_df.groupby(["Total Students"])["Average Reading Score"].mean()
size_passing_math = per_school_summary_df.groupby(["Total Students"])["Percent Passing Math"].mean()
size_passing_reading = per_school_summary_df.groupby(["Total Students"])["Percent Passing Reading"].mean()
size_overall_passing = per_school_summary_df.groupby(["Total Students"])["Percent Overall Passing"].mean()

# %%
# Combine each of the scores above into single DataFrame called `reading_scores_by_grade`
reading_scores_by_grade_df = pd.DataFrame(reading_scores_by_grade_data)


size_summary = {
    "Small (<1000)": "<1000",
    "Medium (1000-2000)": "1000-2000",
    "Large (2000-5000)": "2000-5000"
}

# Create a DataFrame called `size_summary` that breaks down school performance based on school size (small, medium, or large).
# Use the scores above to create a new DataFrame called `size_summary`
size_summary_df = pd.DataFrame(list(size_summary.items()), columns=['Size Category', 'Range'])

# Display results
size_summary_df
# Out:
#         Size Category      Range
# 0       Small (<1000)      <1000
# 1  Medium (1000-2000)  1000-2000
# 2   Large (2000-5000)  2000-5000

# %%
# Group the per_school_summary DataFrame by "School Type" and average the results.
average_math_score_by_type = per_school_summary_df.groupby(["School Type"])["Average Math Score"].mean()
average_math_score_by_type = round(average_math_score_by_type)
average_reading_score_by_type = per_school_summary_df.groupby(["School Type"])["Average Reading Score"].mean()
average_reading_score_by_type = round(average_reading_score_by_type)
average_percent_passing_math_by_type = per_school_summary_df.groupby(["School Type"])["Percent Passing Math"].mean()
average_percent_passing_math_by_type = round(average_percent_passing_math_by_type)
average_percent_passing_reading_by_type = per_school_summary_df.groupby(["School Type"])["Percent Passing Reading"].mean()
average_percent_passing_reading_by_type = round(average_percent_passing_reading_by_type)
average_percent_overall_passing_by_type = per_school_summary_df.groupby(["School Type"])["Percent Overall Passing"].mean()
average_percent_overall_passing_by_type = round(average_percent_overall_passing_by_type)
# print(average_percent_overall_passing_by_type)

# %%
# Create a dictionary of average scores by type

type_summary_data = {
    "Average_Math_Score_by_Type": average_math_score_by_type,
    "Average_Reading_Score_by_Type": average_reading_score_by_type,
    "Average_Percent_Passing_Math_by_Type": average_percent_passing_math_by_type,
    "Average_Percent_Passing_Reading_by_Type": average_percent_passing_reading_by_type,
    "Average_Percent_Overall_Passing_by_Type": average_percent_overall_passing_by_type
}


# Assemble the new data by type into a DataFrame called `type_summary`
type_summary_df = pd.DataFrame(type_summary_data)

# # Minor data wrangling
type_summary_df.index.name = None

# Display results
type_summary_df
# Out:
#           Average_Math_Score_by_Type  Average_Reading_Score_by_Type  \
# Charter                       1428.0                         1473.0
# District                      2563.0                         3118.0
#
#           Average_Percent_Passing_Math_by_Type  \
# Charter                                   94.0
# District                                  67.0
#
#           Average_Percent_Passing_Reading_by_Type  \
# Charter                                      97.0
# District                                     81.0
#
#           Average_Percent_Overall_Passing_by_Type
# Charter                                      90.0
# District                                     54.0
